# %%
import numpy as np
import pandas as pd
from darts import TimeSeries
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/processed/fx_spots_close.csv', index_col = 'Date')

# %%
df.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
log_df = pd.read_csv('../data/processed/log_returns.csv', index_col = 'Date')
log_df.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
series = TimeSeries.from_dataframe(df, "Date", freq='D')

# %%
series.plot()
# Out:
# <Axes: xlabel='Date'>
